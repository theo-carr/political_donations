# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test_df = pd.read_csv('data/indiv22/by_date/itcont_2022_20210221_20210408.txt'
, delimiter='|',
header=None,
names = ['cmte_id', 'amndt_ind','rpt_tp','transaction_pgi','image_num','transaction_tp','entity_tp','name','city','state','zip','employer','occupation','transaction_dt','transaction_amt','other_id','tran_id','file_num','memo_cd','memo_text','sub_id']
)
# Out:
# C:\Users\theoc\AppData\Local\Temp\ipykernel_20132\2472336737.py:1: DtypeWarning: Columns (10,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv('data/indiv22/by_date/itcont_2022_20210221_20210408.txt'

# %%
test_df
# Out:
#            cmte_id amndt_ind rpt_tp transaction_pgi           image_num  \
# 0        C00765347         N    12S           S2021  202103089440358020
# 1        C00765347         N    12S           S2021  202103089440358023
# 2        C00765347         N    12S           S2021  202103089440358024
# 3        C00113241         N     M3               P  202103099440359701
# 4        C00279802         N     M3               P  202103069440285367
# ...            ...       ...    ...             ...                 ...
# 1986924  C00694323         A     MY             NaN  202112209471030403
# 1986925  C00409581         A     Q2           P2022  202211169546805134
# 1986926  C00409581         A     Q2           P2022  202211169546805158
# 1986927  C00694323         A     MY             NaN  202112209471035246
# 1986928  C00694323         A     MY             NaN  202112209471029625
#
#         transaction_tp entity_tp               name            city state  \
# ...

# %%
test_df.nlargest(n=10,columns=['transaction_amt'])
# Out:
#            cmte_id amndt_ind rpt_tp transaction_pgi           image_num  \
# 790236   C00770495         N     MY               P  202107309452400203
# 1212033  C00772020         N     MY               P  202107069450985452
# 1948928  C00688655         N     M5               P  202105209446993207
# 944268   C00683649         N     MY               P  202107169451677284
# 1042301  C00760116         A     MY               P  202201319485798859
# 1611538  C00504530         N     MY               P  202107319465467590
# 1921304  C00559906         N     Q2               P  202107159451379725
# 69413    C00766782         N     Q1               P  202104159443513494
# 977267   C00766782         N     Q1               P  202104159443513480
# 977268   C00766782         N     Q1               P  202104159443513481
#
#         transaction_tp entity_tp  \
# 790236              10       IND
# 1212033             10       IND
# 1948928             10       IND
# 944268              10       IND
# ...
